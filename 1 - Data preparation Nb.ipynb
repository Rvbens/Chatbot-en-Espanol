# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import random
import itertools
import pickle
from settings import *

# %%
#TODO: resumen del proceso
#1 cargar todas diccionario con line index y sentence
#2 elminiar las mas largas de 50
#3 añadir las palabras al vocabulario
#4 eliminar las sentence con palabras que no salen
#5 pasar los pares con line index contiguos

# %%
# n_lines = 0
# with open(corpus, 'rb') as file:
#     for line in file:
#         n_lines += 1
# print(f'Numero de líneas: {n_lines}')

n_lines = 213_517_354
f"Lineas usadas sobre el total:{LINES_USED/n_lines:.3%}"
# Out:
# 'Lineas usadas sobre el total:0.234%'

# %%
def printLines(stop=10, decode=False):
    with open(corpus, 'rb') as datafile:
        for i,line in enumerate(datafile):
            
            if decode:
                print(i,line.decode("utf-8"))
            else:
                print(i,line)
            if i==stop: break

printLines(10,True)
# Out:
# 0 NETKonet trae para ti...
#
# 1 "Twenty"
#
# 2 [NEW Presenta]
#
# 3 [Una producción de A M Tree Pictures]
#
# 4 [Sidus HQ]
#
# 5 [Productor ejecutivo:
#
# 6 Kim Woo Taek]
#
# 7 Somos los típicos amigos de la secundaria que juraron que su amistad duraría para siempre.
#
# 8 Aunque las circunstancias del inicio de nuestra amistad no fueron especiales en cierto modo fueron especiales para nosotros.
#
# 9 Ejem... ejem.
#
# 10 Ejem...

# %%
#funcion para buscar ejemplos a la hora de tratar la puntuacion
def search_line(search_string,stop=10):
    n=0
    prev_line,line_found = "",""
    prnt = False
    
    with open(corpus, 'rb') as datafile:
        for i,line in enumerate(datafile):
            if prnt:
                print("-------------")
                print(prev_line.decode("utf-8"),line_found.decode("utf-8"),
                      line.decode("utf-8"), sep="\n")
                prnt = False
                n+=1
                if n==stop:
                    break
            if search_string in line: 
                line_found = line
                prnt = True
            else:
                prev_line = line
                
search_line(b". ",100)
# Out:
# -------------
# Aunque las circunstancias del inicio de nuestra amistad no fueron especiales en cierto modo fueron especiales para nosotros.
#
# Ejem... ejem.
#
# Ejem...
#
# -------------
# - Háganlo con Piedra, Papel o tijeras.
#
# - Es una buena idea. ¡Hagámoslo!
#
# Ok, solo haremos una ronda, como hombres.
#
# -------------
# Lamento no habértelo dicho primero.
#
# Aunque ahora estemos rompiendo... como amigo y compañero de clase, siempre te desearé lo mejor.
#
# ¡Fighting!
#
# -------------
# Entre el sueño y la realidad.
#
# Hasta este punto, todos los errores que hemos cometido en el pasado... se perdonan porque éramos jóvenes y nos faltaba experiencia en la vida.
#
# Sin embargo, parados aquí, mayores y más experimentados...
#
# -------------
# Hay algo que ustedes no entienden.
#
# Este no es solamente un camino bifurcado... si no que hay tres caminos para elegir.
#
# - Yo iré por este camino.
#
# -------------
# Mi padre murió a los 40, y Mozart murió cuando tenía 35.
#
# - Kurt Cobain murió a los 27. ¡27!
#
# - Kurt Cobain se suicidó.
#
# -------------
# ¿Que compremos un seguro de vida?
#
# Si dividiéramos nuestras vidas a la mitad... pasamos la mitad como menores, y la otra mitad como adultos.
#
# Lo que significa que el punto medio de nuestras vidas... es a los 20 años.
#
# -------------
# ¿Que compremos un seguro de vida?
#
# Lo que significa que el punto medio de nuestras vidas... es a los 20 años.
#
# ¿Ya hemos vivido la mitad de nuestras vidas?
#
# -------------
# Entonces, ¿en dónde quedó mi historia?
#
# Yo... no quiero convertirme en un monstruo.
#
# Señor, estoy en contra de la idea de la prostitución... así que no tengo idea de cómo, cuándo o dónde voy a tener sexo.
#
# -------------
# Entonces, ¿en dónde quedó mi historia?
#
# Señor, estoy en contra de la idea de la prostitución... así que no tengo idea de cómo, cuándo o dónde voy a tener sexo.
#
# No tengas miedo.
#
# -------------
# Ya estás listo.
#
# Solo... solo...
#
# ¿Cómo digo esto...?
#
# -------------
# En cambio, incomódala a ella.
#
# Entonces... vas y rematas.
#
# Quiero frotar mi pene por todo tu trasero.
#
# -------------
# Para entonces tus órganos reproductores masculinos habrán madurado hace rato.
#
# Pero el sistema educativo de nuestra nación ha ignorado esa realidad... y trabajado para mantener esa verdad estrictamente oculta de nosotros.
#
# Solo han enfatizado la necesidad de logros académicos... y pisoteado completamente nuestros apremiantes deseos naturales por la carne.
#
# -------------
# Para entonces tus órganos reproductores masculinos habrán madurado hace rato.
#
# Solo han enfatizado la necesidad de logros académicos... y pisoteado completamente nuestros apremiantes deseos naturales por la carne.
#
# forzándonos a vivir como monjes en celibato.
#
# -------------
# Observen, amigos.
#
# El divino Buda ha oído nuestras plegarias... y nos está dando su bendición para que unamos nuestras carnes como uno solo.
#
# ¿Unimos nuestros cuerpos?
#
# -------------
# Mamá, algo le pasa a Kyung Jae.
#
# No deja de golpearse la ingle mientras mira gritar a un lunático... en su computadora.
#
# Deja dormir a mamá y te lo explicaré.
#
# -------------
# ¿Cómo has estado?
#
# Sé que tu escuela no está cerca, así que... ¿Qué te trae por aquí?
#
# No es tan lejos.
#
# -------------
# Ni siquiera hablemos de fin de año, porque no soy esa clase de persona...
#
# Antes de fin de año... pensaré seriamente en qué quiero hacer...
#
# Así que... qué mi mesada siga fluyendo.
#
# -------------
# Ni siquiera hablemos de fin de año, porque no soy esa clase de persona...
#
# Así que... qué mi mesada siga fluyendo.
#
# Acordemos eso, ¿OK?
#
# -------------
# Ya ni siquiera tengo un ingreso, y no puedo salir con una chica pobre como tú.
#
# Aunque ahora solo pueda darte rábanos en vinagre... tendré un brillante futuro por delante cuando me reciba de la universidad.
#
# Pero el presente me importa más.
#
# -------------
# Mi novio suele volver pronto, también.
#
# ¿Tu novio también es un... jugador?
#
# Deben chuparla como hombres.
#
# -------------
# Igualmente, esa era tu intención.
#
# Eh, espera... ¿en serio?
#
# ¿Realmente vas a seducirla?
#
# -------------
# ¿A qué te dedicas?
#
# Durante el día... a sentarme quieto.
#
# Y a la noche, o salgo a tomar algo...
#
# -------------
# La tendrá la semana que viene.
#
# Bien. ¿Y tú por qué te agachas?
#
# Estoy simpatizando con los pobres.
#
# -------------
# ]
#
# Eh... tengo una pregunta que quisiera hacerle.
#
# Claro, ¿qué es?
#
# -------------
# ¿No puedes ver que estoy yendo?
#
# Estoy en camino... hacia ti.
#
# Ese idiota es un imbécil.
#
# -------------
# ¿Así cómo?
#
# Como si pensaras con tu corazón... en vez de con tu pene.
#
# Como si quisieras abrazarla en vez de tirártela.
#
# -------------
# Te equivocas.
#
# Guau... me pregunto si esto también desaparecerá.
#
# Así es la vida.
#
# -------------
# - Alguien a quién veo para tener sexo.
#
# - Extrañamente... tiene sentido.
#
# - Entonces... ¿Estar enamorado?
#
# -------------
# - Alguien a quién veo para tener sexo.
#
# - Entonces... ¿Estar enamorado?
#
# - Hacerlo muchas veces al día.
#
# -------------
# [Para tu deleite visual.]
#
# Ajj... esa loca.
#
# - ¿Debería hacerme un lunar?
#
# -------------
# Si yo hubiera caído con él, ¿quién se hubiera ocupado de la familia?
#
# Y... ni siquiera tu padre me guarda rencor por lo que ocurrió.
#
# - ¿A dónde vas?
#
# -------------
# Por favor, se los ruego.
#
# Borren... lo que acaban de grabar.
#
# Por favor, se los ruego.
#
# -------------
# Suficiente.
#
# Quiero que te vayas. ¡Vete!
#
# Está bien, sigan comiendo.
#
# -------------
# Pero estoy seguro de que está siendo tratada más cálidamente que aquí.
#
# Aquí... me duele justo aquí.
#
# ¿Saben cómo se siente?
#
# -------------
# - Es porque lo has estado frotando.
#
# - Para ti. ¿Puedo conseguirte algo más?
#
# - Piérdete.
#
# -------------
# - ¿Qué?
#
# He estado viendo muchas películas últimamente... los adolescentes se suicidan todo el tiempo.
#
# Deberías suicidarte.
#
# -------------
# El primer par de tetas que toqué fue el sostén relleno de una desconocida que ni conocía.
#
# Mi primer par de tetas fue... un sostén relleno barato, de poliéster, poliuretano y algodón.
#
# Y fue ahí cuando me desmayé.
#
# -------------
# Invasión del planeta Pene.
#
# Pene... como...
#
# Ah... ¿pene?
#
# -------------
# Invasión del planeta Pene.
#
# Ah... ¿pene?
#
# Ok, continúa.
#
# -------------
# Pero los machos veían sus nuevos penes como símbolo de orgullo e iban por ahí alardeando de ellos.
#
# Hasta que... comenzaron a evolucionar hasta lo que son hoy en día.
#
# Nuestros penes son aliens.
#
# -------------
# ¿pero usas suavizante para la ropa?
#
# Bueno... tengo piel sensible.
#
# No pierdas a otra buena chica.
#
# -------------
# Encontrémonos en Soh Soh a las 3 p.m.]
#
# Creo que estoy... nerviosa.
#
# Yo hablaré.
#
# -------------
# No hay sitio para ti.
#
# Vaya. ¿Cómo puedes ser tan voluble?
#
# Me dijiste que me mudara, la última vez.
#
# -------------
# - A lo grande.
#
# Y... mierda.
#
# Lo más patético es...
#
# -------------
# Absolutamente no.
#
# ¿Por qué se siente tan... vacío?
#
# La gente no para de decir que estos son los mejores años de nuestras vidas.
#
# -------------
# Este hombre que ha estado conteniendo sus instintos salvajes...
#
# Está... a punto de explotar.
#
# Pero siempre pago mis intereses a tiempo.
#
# -------------
# Ey, ¿qué pasa con tus notas?
#
# Soy estudiante universitario. ¿Y qué?
#
# Sigues siendo un estudiante.
#
# -------------
# No les hará ningún bien ocultarse tras la generosidad de Cutter.
#
# Suéltenlo ya. ¿Un mapa de qué?
#
# Del lago Singali, señor.
#
# -------------
# Meteos ahí, ¿me oís?
#
# Vamos, adentro. ¡Rápido!
#
# Eso es.
#
# -------------
# Eso es.
#
# Parapetaos tras el muro, vamos. ¡Deprisa!
#
# - ¿Agua, sahib sargento?
#
# -------------
# Yo lo llamo bazofia.
#
# Tonterías, Stebbins es famoso por su ponche. ¿Quiere un poco?
#
# Cómo no.
#
# -------------
# Sahib.
#
# El bueno de Din. ¿Qué pasa?
#
# Esta noche, cuando todos duerman, volveré.
#
# -------------
# Buenos días, caballeros.
#
# Buenos días. ¿Qué hace aquí?
#
# He venido a reemplazar al sargento Ballantine.
#
# -------------
# ¡Esta vez acabas en el paredón!
#
# Espera, Mac. ¿Dónde está Cutter?
#
# Din, ¿dónde está el sargento Cutter?
#
# -------------
# - No, no irás.
#
# - Tommy, cariño. ¿Qué ocurre?
#
# - Nada.
#
# -------------
# Será el siguiente.
#
# Estoy esperando. ¿Hablará?
#
# - No lo sé.
#
# -------------
# Basta.
#
# Mire. ¿Las ve, retorciéndose y sacando sus bonitas lenguas?
#
# ¿Va a hablar?
#
# -------------
# - A la libertad no.
#
# - Ya lo veremos. ¿Listos?
#
# - Sí.
#
# -------------
# Muy bien, tío listo, ésta es mi última oferta.
#
# Ordenas a tus hombres que vayan tras las rocas, nos acompañas hasta el puente, te dejamos ir, y no habrá pasado nada. ¿Qué te parece?
#
# Habla, macaco, o te mato.
#
# -------------
# como despedazamos hasta el último hombre.
#
# Como ve, no todo es guerra en el ejército, Sr. Periodista.
#
# Están llegando.
#
# -------------
# Y...
#
# Enséñeme la última parte, ¿quiere, Sr. Kipling?
#
# ¡Presenten armas!
#
# -------------
# La traidora
#
# Dramático episodio de guerra De D. J. Rector
#
# Film original de
#
# -------------
# Subteniente von Mallwitz
#
# - Rob. von Valberg.
#
# Vujrat, líder de los partisanos
#
# -------------
# Él, les explica la naturaleza de la misión de Dante en el Infierno.
#
# El lugar es habitado por las vidas intachables... de los que murieron antes de la llegada de Jesucristo.
#
# Virgilio señala a Dante a poetas, filósofos, políticos y científicos confinados en este lugar.
#
# -------------
# El río de la suciedad en el que lisonjeros y disolutos se sumergen y donde buscan en vano, bañarse para limpiarse.
#
# Los Simoniacos, que eran aquellos que vendían los bienes de la iglesia, eran enterrados cabeza abajo, y con sus pies hacia arriba... y atormentados por un fuego de gran intensidad sobre las plantas de los pies.
#
# Uno que había sido el principal de su iglesia, castigado aquí, es denunciado por Dante.
#
# -------------
# Uno que había sido el principal de su iglesia, castigado aquí, es denunciado por Dante.
#
# Virgilio aplaca a los demonios que vigilan este círculo, dónde los que se han apropiado de dinero o propiedades ajenas... son castigados, siendo sumergidos en un río de alquitrán hirviente.
#
# Ciampollo de Navarra, cae en poder de los demonios que van a despedazarlo.
#
# -------------
# Ciampollo de Navarra, cae en poder de los demonios que van a despedazarlo.
#
# Él distrae su atención y se escapa... saltando en el lago de alquitrán hirviente donde los demonios son incapaces de recapturarlo.
#
# Los poetas vuelan hacia adentro del siguiente círculo donde los demonios son incapaces de perseguirles, ...ya que el Poder Divino les da el control de su propio círculo, pero no les permite abandonarlo.
#
# -------------
# Obligan a los hipócritas a llevar grandes y pesadas capas, que en apariencia son de oro, pero por dentro son de plomo.
#
# Dante, ve al hipócrita Caifás,... quien condenó a Cristo a morir, clavado y crucificado al suelo.
#
# Dante está ansioso de descansar, pero es instado por Virgilio quién le dice que en caso de necesidad, contarán con la ayuda Divina.
#
# -------------
# Mahoma se muestra con su pecho rasgado y lacerado.
#
# Fraudulentos, falsificadores, alquimistas y simuladores... están convertidos en leprosos, enfermos e insanos.
#
# Dante comienza a discutir airadamente con algunos que él conocía en vida... y finalmente es reprendido por Virgilio:
#
# -------------
# Mahoma se muestra con su pecho rasgado y lacerado.
#
# Dante comienza a discutir airadamente con algunos que él conocía en vida... y finalmente es reprendido por Virgilio:
#
# "Escuchar discusiones como esta es una alegría para las mentes vulgares".
#
# -------------
# El conde Hugolino roe el cráneo del Arzobispo Rugieri.
#
# "Sus mandíbulas se levantan de su comida caída. "
#
# El Conde Hugolino relata a Dante... como, tras pelear con su amigo el Arzobispo, él, sus hijos y nietos se morían de hambre en la "Torre de Pisa" por orden del Arzobispo.
#
# -------------
# El conde Hugolino roe el cráneo del Arzobispo Rugieri.
#
# El Conde Hugolino relata a Dante... como, tras pelear con su amigo el Arzobispo, él, sus hijos y nietos se morían de hambre en la "Torre de Pisa" por orden del Arzobispo.
#
# El conde ve a su familia fallecer delante de sus ojos y al sexto día, solo queda él.
#
# -------------
# Bien, eso es.
#
# Eso ya está. ¿Ahora qué?
#
# Bien.
#
# -------------
# Bien, ahora pasemos a tu...
#
# Hace unos años, queríamos... tratar de colaborar con algunos activistas anti-corporativos.
#
# Y los visitamos, y ellos-- y nos preguntaron si nos gustaría hacer un sitio web que criticara a George Bush.
#
# -------------
# Tiene que haber límites--tiene que haber límites a la libertad.
#
# Pero... sabemos del sitio.
#
# Y este tipo no es más que un basurero.
#
# -------------
# En realidad, lo que hizo fue ayudar a las grandes corporaciones a que vayan y exploten a esos pueblos aúun más para que los estadounidenses se vuelvan todavía más ricos y la gente de estos países siga luchando por sobrevivir.
#
# Y yo creo que eso--hasta ahora sólo preocupa a pocas personas. una parodia con el mismo diseño que el sitio verdadero de la OMC.
#
# En la primavera de 2001, llegó un e-mail que le pedía a la OMC que disertara en una conferencia:
#
# -------------
# Cuando preguntan creen realmente que están hablando con la OMC, y nosotros les respondemos con lo que creemos que quieren-- es decir, la opinión de la OMC--- con la mayor precisión con que podemos imitarlos.
#
# Sabes, lo que pienso, en verdad, cuando veo esto... es que tal vez aquí sería mejor poner un cierre.
#
# ¡Sí!
#
# -------------
# - Eso sería muy bueno.
#
# - Porque... si hacemos que explote por el Velcro, quizá no tenga la fuerza suficiente y entonces él lo tendría que sacar.
#
# Una parte de lo que nos da valor para ir a Tampere...
#
# -------------
# con este traje realmente absurdo es que ya fuimos a Salzburgo, en Austria, en representación de la OMC en una conferencia que trataba sobre tarifas y comercio.
#
# Nuestro representante--el que hace de Hank Hardy Unruh aquí era el Dr. Andreas Bichlbauer allí.
#
# Dio una conferencia que se centró en eliminar todas las costumbres en nombre del libre comercio, como por ejemplo eliminar la siesta en España y en Italia para que los horarios comerciales fueran los mismos.
#
# -------------
# Y permitirle a la gente vender sus votos por Internet al mejor postor y así sacar del medio las barreras al libre comercio y los votos.
#
# En la política estadounidense se está probando una solución posible para optimizar el sistema electoral, que es de una ineficiencia atroz. para transmitir no sólo información, sino también dinero directamente al votante consumidor.
#
# Un foro para que la gente ofrezca a voluntad su voto al mejor postor.
#
# -------------
# Bien, hasta ahora pensamos que Bichlbauer sería el extremo y que la gente reaccionaría y que nos harían desaparecer, y no pasó nada de eso.
#
# Así que... esta vez tenemos que exagerar del todo y llegar al extremo.
#
# Realmente tratamos de llevar las cosas aúun más lejos para dejar bien en claro la posición de la OMC y hacerla muy legible.
#
# -------------
# A veces creo que ellos no saben qué diablos esperar de mí.
#
# Lo que invento... muchas veces no es lo que ellos tenían en mente, pero es... es decir, encaja perfectamente con lo que van a hacer.
#
# Bueno, yo salí de un ambiente corporativo y una empresa a la que realmente le di una buena parte de mi alma progresivamente durante mucho tiempo.
#
# -------------
# Volvía a casa, en verdad, porque había estado fuera-- había estado en la Costa Oeste unos 12 años.
#
# Un momento. ¿qué es esto?
#
# Esto es...
#
# -------------
# "Los muertos no mienten".
#
# Y así logramos que les devolvieran las góndolas... en todo el país en el marco de lo que llamamos "Programa Devolución".
#
# Somos como Papá Noel, sólo que menos radicales porque Papá Noel se mete en las casas de la gente.
#
# -------------
# Fue muy gracioso, suena como:
#
# "Vengan, luchen. ¡Luchen!"
#
# - Excepto que dice...
#
# -------------
# - Excepto que dice...
#
# - Me encanta la escuela. ¿Y a ti?
#
# ¡Cantemos con la banda esta noche!
#
# -------------
# Hagamos una lista.
#
# El miércoles salimos para Finlandia temprano, y el domingo... preparamos el discurso.
#
# ¿Más grande?
#
# -------------
# Los Líderes Mundiales Acuerdan
#
# Son las 4:30 a.m. y creo que seguiré trabajando hasta más tarde.
#
# Me siento... como despierto.
#
# -------------
# Los Líderes Mundiales Acuerdan
#
# Me siento... como despierto.
#
# Y después Andy puede retomar.
#
# -------------
# Si la OMC quiere encarar con seriedad la pobreza mundial, haría cosas totalmente distintas de las que hace hoy.
#
# Permítame mencionar a Granwyth sobre eso. ¿Le parece que es justo?
#
# Bueno, claro que sí, pero creo que Barry y los demás manifestantes están demasiado concentrados en la realidad y en hechos y en cifras.
#
# -------------
# ¿Parece oficial?
#
# Muy... muy llamativo.
#
# Bien.
#
# -------------
# ¿Y estás tan nervioso como lo estabas cuando Salzburgo?
#
# El tema es que, cuando fue lo de Salzburgo, entramos en el asunto, como... un poco-- realmente muy nerviosos, pero todo el tiempo fue-- no te das cuenta hasta que estás ahí.
#
# Correcto.
#
# -------------
# Son las 8:30, ¿no?
#
# - Pero Ud. tendrá...
#
# - Son las 8:30... ¿no es así?
#
# -------------
# Son las 8:30, ¿no?
#
# - Son las 8:30... ¿no es así?
#
# Son...
#
# -------------
# Son...
#
# las... 9:30, sí.
#
# - ¿Ahora?
#
# -------------
# - De acuerdo, nosotros...
#
# ¿Ud. también viene?
#
# ¿Ya se registró?
#
# -------------
# Oh, Dios.
#
# Bien... genial.
#
# - Tiene un poco de aire adentro.
#
# -------------
# Me complace y me alegra presentarles
#
# a nuestro próximo orador, el Sr. Hank Hardy Unruhm, que tiene un Postgrado en Administración de la Universidad de Texas, Austin.
#
# Hank Hardy Unruh se crió en Montopolis, Texas.
#
# -------------
# Actualmente vive en París.
#
# El título de la presentación del Sr. Unruh es el Futuro de los Textiles:
#
# El Futuro de una Vida, y la Vida del Futuro".

# %%
#Procesado de la puntuación
def process_punct(s):#complejo
    s = s.strip().lower().decode()
    s = re.sub(r"\.000",r" mil", s)
    s = re.sub(r"^-",       r"<GUION_INIC>", s)
    s = re.sub(r"-{2}",     r"<GUION_DOBL>", s)
    s = re.sub(r"\.{3}",    r"<TRIP_DOT>", s)
    s = re.sub(r"{y:bi}",   r"<SPECIAL_1>", s)
    s = re.sub(r"(\w)-(\w)",r"\1<GUION_INTER>\2", s)
    s = re.sub(r"([\):!?])",r" \1", s)      #separa puntuacion con espacio antes
    s = re.sub(r"([\(¡¿])", r"\1 ", s)      #separa puntuacion con espacio despues
    s = re.sub(r"([\"-,¿\.}])", r" \1 ", s) #espacio antes y despues
    
    #separa los tokens
    s = re.sub(r"<", r" <", s)
    s = re.sub(r">", r"> ", s)
    
    s = re.sub(r"\s<GUION_INTER>\s",r"-", s)
    return s

import unicodedata
def process_punct(s): #simple #punct2
    s = s.strip().lower().decode()
    s = re.sub(r"^-",       r"<GUION_INIC>", s)
    s = re.sub(r"\.{3}",    r"<TRIP_DOT>", s)
    s = re.sub(r"{y:bi}",   r"<TKN_A>", s)
    s = ''.join((c for c in unicodedata.normalize('NFD',s) if unicodedata.category(c) != 'Mn')) #quita tildes
    s = re.sub(r"([.¡!¿?])", r" \1 ", s)
    s = re.sub(r"[^a-zA-Z.¡!¿?<>_\d]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    
    s = re.sub(r"<", r" <", s)
    s = re.sub(r">", r"> ", s)
    return s

def process_punct(l): #basico punct3
    s = l.lstrip(b"-").strip().lower().decode() #elimina guion del principio de algunas lineas
    s = re.sub(r"([.!?])", r" \1", s) #separa puntuacion
    s = re.sub(r"([.¡¿])", r"\1 ", s) #separa puntuacion
    s = re.sub(r"[,]",r"",s) #quita las comas
    return s

print("#Test  0:", process_punct("-t. -t".encode()))
print("#Test  1:", process_punct("t. .t ¿t? ¿¿¿t???".encode()))
print("#Test  2:", process_punct("".encode()))
print("#Test  3:", process_punct("...t...".encode()))
print("#Test  4:", process_punct("???...!!!".encode()))
print("#Test  5:", process_punct('"¿Cómo?"'.encode()))
print("#Test  6:", process_punct('(--8:)'.encode()))
print("#Test  7:", process_punct('electro-quimico'.encode()))
print("#Test  8:", process_punct('que--'.encode()))
print("#Test  9:", process_punct('-ivanov'.encode()))
print("#Test 10:", process_punct('10.000, 5:45'.encode()))
print("#Test 11:", process_punct('8:00 8:00h'.encode()))
print("#Test 12:", process_punct('.¿ -¿'.encode()))
print("#Test 13:", process_punct('{y:bi}vamos'.encode()))
# Out:
# #Test  0: t .  -t
# #Test  1: t .   . t ¿ t ? ¿ ¿ ¿ t ? ? ?
# #Test  2:
# #Test  3:  .  .  . t .  .  .
# #Test  4:  ? ? ? .  .  .  ! ! !
# #Test  5: "¿ cómo ?"
# #Test  6: (--8:)
# #Test  7: electro-quimico
# #Test  8: que--
# #Test  9: ivanov
# #Test 10: 10 . 000 5:45
# #Test 11: 8:00 8:00h
# #Test 12:  . ¿  -¿
# #Test 13: {y:bi}vamos

# %%
def loadLines(file, total_lines=10, max_lenght=MAX_LENGTH):
    with open(file, 'rb') as datafile:
        n=0
        for i,line in enumerate(datafile):
            if max(line.find(b"["),line.find(b"]")) == -1: #filtra los comentarios
                s = process_punct(line)
                s = s.strip().split()
                if len(s) < max_lenght: #filtra frases largas
                    n+=1
                    yield i,s
            if n==total_lines: break
                
# for i,l in loadLines(corpus,10): print(i,l)

# %%
# Default word tokens
class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {"UNK": UNK_token}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, spl_sent):
        for word in spl_sent:
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print(f"keep_words {len(keep_words)} / { len(self.word2index)} = "
              f"{len(keep_words) / len(self.word2index):.4f}")

        # Reinitialize dictionaries
        self.word2index = {"UNK": UNK_token}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS", UNK_token:"UNK"}
        self.num_words = 4 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
# %%time
#TODO: multicpu
voc = Voc(corpus_name)

hist = []  
for i,s in loadLines(corpus,LINES_USED):
    s_l = len(s)
    hist.append(s_l)
    voc.addSentence(s)
    
print(f'Número de palabras: {voc.num_words}')

arr = np.array(hist)
plt.hist(arr, bins='auto')  # arguments are passed to np.histogram
plt.title(f"Sentence lenght. Capped to {MAX_LENGTH}")
plt.show()
# Out:
# Número de palabras: 57475
# CPU times: user 15.3 s, sys: 132 ms, total: 15.5 s
# Wall time: 15.4 s

# %%
hist=[]
for i,n in enumerate(voc.word2count):
    c = voc.word2count[n]
    if c>=3:
        hist.append(c)
        
arr = np.array(hist)
plt.hist(arr, bins=100,range=(3,50))  # arguments are passed to np.histogram
plt.title(f"Word frequency. Showing only: >=3,<50")
plt.show()

# %%
from collections import Counter
c = Counter(voc.word2count)
c.most_common()
# Out:
# [('.', 420869),
#  ('?', 93966),
#  ('¿', 88018),
#  ('no', 79166),
#  ('que', 75467),
#  ('de', 70948),
#  ('a', 56316),
#  ('la', 51559),
#  ('el', 45073),
#  ('!', 41711),
#  ('es', 39387),
#  ('¡', 37955),
#  ('y', 37425),
#  ('lo', 34595),
#  ('en', 34327),
#  ('un', 33126),
#  ('qué', 28337),
#  ('me', 28013),
#  ('por', 27317),
#  ('se', 20972),
#  ('una', 20746),
#  ('te', 17411),
#  ('los', 17023),
#  ('con', 16690),
#  ('sí', 15533),
#  ('está', 14073),
#  ('para', 13813),
#  ('pero', 13665),
#  ('si', 13594),
#  ('le', 12977),
#  ('yo', 12446),
#  ('su', 12279),
#  ('las', 11999),
#  ('mi', 11975),
#  ('al', 11100),
#  ('eso', 10561),
#  ('bien', 10339),
#  ('ha', 9897),
#  ('aquí', 9792),
#  ('más', 9486),
#  ('del', 9453),
#  ('como', 8356),
#  ('ya', 8239),
#  ('muy', 7589),
#  ('todo', 7397),
#  ('he', 7320),
#  ('señor', 7099),
#  ('usted', 6436),
#  ('hay', 6285),
#  ('nada', 6238),
#  ('ahora', 5897),
#  ('tu', 5796),
#  ('tiene', 5778),
#  ('gracias', 5621),
#  ('cómo', 5570),
#  ('algo', 5515),
#  ('tengo', 5511),
#  ('así', 5479),
#  ('nos', 5467),
#  ('estoy', 5182),
#  ('esta', 5150),
#  ('vamos', 5086),
#  ('sé', 5070),
#  ('cuando', 4903),
#  ('puede', 4816),
#  ('quiero', 4813),
#  ('esto', 4761),
#  ('tú', 4739),
#  ('sólo', 4509),
#  ('este', 4301),
#  ('soy', 4192),
#  ('o', 4127),
#  ('vez', 4117),
#  ('bueno', 4045),
#  ('verdad', 4041),
#  ('era', 3934),
#  ('quién', 3887),
#  ('todos', 3880),
#  ('él', 3837),
#  ('son', 3766),
#  ('puedo', 3765),
#  ('mejor', 3728),
#  ('tan', 3723),
#  ('ser', 3692),
#  ('mí', 3676),
#  ('dónde', 3672),
#  ('sr', 3642),
#  ('ese', 3599),
#  ('hacer', 3532),
#  ('quiere', 3531),
#  ('favor', 3488),
#  ('has', 3480),
#  ('hombre', 3452),
#  ('mucho', 3393),
#  ('voy', 3380),
#  ('casa', 3320),
#  ('también', 3273),
#  ('ella', 3271),
#  ('dos', 3247),
#  ('tiempo', 3193),
#  ('estás', 3158),
#  ('creo', 3150),
#  ('hace', 3144),
#  ('nunca', 3137),
#  ('sus', 3083),
#  ('fue', 3073),
#  ('hasta', 2958),
#  ('va', 2935),
#  ('porque', 2906),
#  ('ni', 2901),
#  ('siempre', 2860),
#  ('noche', 2830),
#  ('esa', 2815),
#  ('sin', 2796),
#  ('ver', 2688),
#  ('tienes', 2667),
#  ('nadie', 2667),
#  ('estaba', 2624),
#  ('otra', 2585),
#  ('ahí', 2561),
#  ('uno', 2555),
#  ('vida', 2553),
#  ('eres', 2548),
#  ('sabe', 2538),
#  ('les', 2520),
#  ('claro', 2509),
#  ('entonces', 2506),
#  ('antes', 2500),
#  ('han', 2485),
#  ('hola', 2455),
#  ('decir', 2425),
#  ('están', 2422),
#  ('mañana', 2418),
#  ('parece', 2389),
#  ('mujer', 2367),
#  ('día', 2366),
#  ('quieres', 2325),
#  ('será', 2256),
#  ('poco', 2229),
#  ('sobre', 2227),
#  ('hecho', 2222),
#  ('ti', 2199),
#  ('sabes', 2193),
#  ('siento', 2165),
#  ('alguien', 2144),
#  ('padre', 2104),
#  ('cosas', 2101),
#  ('mis', 2093),
#  ('mismo', 2091),
#  ('pasa', 2019),
#  ('nosotros', 2013),
#  ('hablar', 2006),
#  ('otro', 1990),
#  ('seguro', 1987),
#  ('oh', 1983),
#  ('pues', 1963),
#  ('hombres', 1947),
#  ('podría', 1937),
#  ('tenemos', 1932),
#  ('tal', 1900),
#  ('días', 1879),
#  ('momento', 1877),
#  ('desde', 1865),
#  ('sea', 1853),
#  ('solo', 1841),
#  ('visto', 1833),
#  ('ir', 1816),
#  ('dicho', 1813),
#  ('estar', 1787),
#  ('años', 1773),
#  ('buenas', 1767),
#  ('dijo', 1766),
#  ('había', 1765),
#  ('debe', 1742),
#  ('tenía', 1718),
#  ('trabajo', 1718),
#  ('coronel', 1711),
#  ('dinero', 1709),
#  ('sido', 1700),
#  ('dios', 1685),
#  ('estamos', 1682),
#  ('allí', 1672),
#  ('después', 1653),
#  ('fuera', 1645),
#  ('dice', 1635),
#  ('acuerdo', 1625),
#  ('gente', 1596),
#  ('puedes', 1588),
#  ('ellos', 1588),
#  ('cosa', 1583),
#  ('chico', 1551),
#  ('mal', 1545),
#  ('vaya', 1544),
#  ('mira', 1507),
#  ('ud', 1504),
#  ('luego', 1496),
#  ('menos', 1492),
#  ('tres', 1491),
#  ('vas', 1489),
#  ('eh', 1483),
#  ('donde', 1478),
#  ('mundo', 1461),
#  ('señora', 1459),
#  ('buena', 1458),
#  ('hijo', 1454),
#  ('conmigo', 1453),
#  ('gusta', 1441),
#  ('demasiado', 1432),
#  ('gran', 1420),
#  ('estado', 1400),
#  ('importa', 1394),
#  ('adiós', 1391),
#  ('noches', 1389),
#  ('tanto', 1385),
#  ('tarde', 1350),
#  ('amigo', 1349),
#  ('aún', 1349),
#  ('venga', 1333),
#  ('razón', 1308),
#  ('tener', 1306),
#  ('hemos', 1298),
#  ('buen', 1293),
#  ('cree', 1287),
#  ('toda', 1285),
#  ('hora', 1282),
#  ('nuestro', 1273),
#  ('debo', 1271),
#  ('srta', 1270),
#  ('ve', 1265),
#  ('quería', 1263),
#  ('ven', 1251),
#  ('hoy', 1228),
#  ('ah', 1219),
#  ('lugar', 1213),
#  ('podemos', 1204),
#  ('quizá', 1193),
#  ('todas', 1183),
#  ('os', 1182),
#  ('"', 1178),
#  ('parte', 1163),
#  ('guerra', 1156),
#  ('caso', 1148),
#  ('general', 1145),
#  ('suerte', 1141),
#  ('da', 1140),
#  ('haber', 1133),
#  ('cierto', 1130),
#  ('tus', 1129),
#  ('sra', 1129),
#  ('sabía', 1122),
#  ('esos', 1122),
#  ('dije', 1116),
#  ('miedo', 1114),
#  ('buenos', 1114),
#  ('hacerlo', 1104),
#  ('espera', 1104),
#  ('cada', 1101),
#  ('veo', 1099),
#  ('crees', 1096),
#  ('alguna', 1095),
#  ('gustaría', 1093),
#  ('amor', 1061),
#  ('unos', 1047),
#  ('nuevo', 1045),
#  ('viejo', 1044),
#  ('veces', 1036),
#  ('pasado', 1022),
#  ('adelante', 1019),
#  ('tipo', 1003),
#  ('nombre', 994),
#  ('tienen', 989),
#  ('doctor', 989),
#  ('idea', 985),
#  ('chica', 980),
#  ('salir', 980),
#  ('algún', 980),
#  ('muchas', 977),
#  ('esposa', 976),
#  ('entre', 973),
#  ('madre', 968),
#  ('papá', 960),
#  ('mío', 958),
#  ('van', 950),
#  ('cabeza', 949),
#  ('contigo', 945),
#  ('nuestra', 942),
#  ('amigos', 939),
#  ('debería', 932),
#  ('sería', 932),
#  ('pronto', 929),
#  ('saber', 929),
#  ('capitán', 929),
#  ('supongo', 922),
#  ('contra', 920),
#  ('cuánto', 916),
#  ('espero', 915),
#  ('cuenta', 912),
#  ('esas', 912),
#  ('quien', 909),
#  ('hizo', 896),
#  ('Él', 886),
#  ('vale', 877),
#  ('io', 872),
#  ('casi', 864),
#  ('quizás', 864),
#  ('cariño', 863),
#  ('puerta', 862),
#  ('muerto', 852),
#  ('pueden', 842),
#  ('haré', 841),
#  ('entiendo', 840),
#  ('muerte', 828),
#  ('estos', 826),
#  ('agua', 824),
#  ('morir', 820),
#  ('dentro', 819),
#  ('habla', 818),
#  ('mamá', 816),
#  ('viene', 816),
#  ('primero', 815),
#  ('culpable', 810),
#  ('volver', 807),
#  ('todavía', 806),
#  ('señorita', 804),
#  ('importante', 803),
#  ('digo', 799),
#  ('oído', 799),
#  ('haces', 793),
#  ('iba', 793),
#  ('ninguna', 791),
#  ('diga', 788),
#  ('ustedes', 787),
#  ('camino', 778),
#  ('fin', 778),
#  ('orden', 778),
#  ('minutos', 778),
#  ('mientras', 777),
#  ('lado', 770),
#  ('estas', 768),
#  ('igual', 765),
#  ('joven', 755),
#  ('marido', 755),
#  ('ojos', 753),
#  ('teniente', 753),
#  ('the', 750),
#  ('vete', 747),
#  ('cuidado', 744),
#  ('nueva', 744),
#  ('rápido', 741),
#  ('loco', 738),
#  ('fuerte', 736),
#  ('policía', 734),
#  ('habrá', 733),
#  ('hacia', 732),
#  ('supuesto', 732),
#  ('venido', 731),
#  ('ningún', 729),
#  ('oye', 720),
#  ('llama', 719),
#  ('iré', 715),
#  ('pasar', 713),
#  ('cualquier', 712),
#  ('sangre', 711),
#  ('vi', 710),
#  ('otros', 708),
#  ('serio', 706),
#  ('queda', 703),
#  ('feliz', 699),
#  ('mano', 699),
#  ('posible', 699),
#  ('ves', 697),
#  ('cinco', 696),
#  ('aunque', 695),
#  ('niño', 694),
#  ('vivir', 692),
#  ('pueblo', 692),
#  ('somos', 689),
#  ('deja', 689),
#  ('manos', 688),
#  ('problemas', 688),
#  ('bastante', 687),
#  ('mire', 686),
#  ('debemos', 683),
#  ('dormir', 683),
#  ('siquiera', 683),
#  ('tierra', 682),
#  ('tenido', 681),
#  ('toma', 680),
#  ('necesito', 680),
#  ('haya', 678),
#  ('muchos', 678),
#  ('conozco', 677),
#  ('ciudad', 677),
#  ('hermano', 676),
#  ('tren', 676),
#  ('falta', 675),
#  ('corazón', 671),
#  ('punto', 670),
#  ('cuándo', 669),
#  ('sigue', 669),
#  ('primera', 667),
#  ('tampoco', 664),
#  ('pensé', 664),
#  ('único', 663),
#  ('cuál', 660),
#  ('pensar', 660),
#  ('horas', 660),
#  ('haciendo', 657),
#  ('haga', 657),
#  ('sitio', 656),
#  ('seis', 656),
#  ('jefe', 655),
#  ('alto', 655),
#  ('listo', 654),
#  ('e', 653),
#  ('puesto', 652),
#  ('durante', 646),
#  ('pregunta', 645),
#  ('cuanto', 642),
#  ('historia', 640),
#  ('mujeres', 639),
#  ('basta', 635),
#  ('dices', 634),
#  ('cuatro', 633),
#  ('000', 632),
#  ('trabajar', 623),
#  ('ayuda', 622),
#  ('adónde', 622),
#  ('problema', 617),
#  ('mayor', 617),
#  ('dado', 617),
#  ('venir', 613),
#  ('llegar', 611),
#  ('asunto', 611),
#  ('hablando', 609),
#  ('cara', 608),
#  ('juntos', 604),
#  ('hubiera', 604),
#  ('allison', 604),
#  ('tenga', 602),
#  ('matar', 602),
#  ('habría', 602),
#  ('bajo', 601),
#  ('hice', 601),
#  ('diré', 600),
#  ('semana', 595),
#  ('perdido', 595),
#  ('número', 595),
#  ('caballeros', 594),
#  ('arriba', 593),
#  ('pueda', 592),
#  ('soldado', 591),
#  ('necesita', 590),
#  ('suficiente', 589),
#  ('meses', 589),
#  ('justo', 589),
#  ('vole', 589),
#  ('déjame', 588),
#  ('unas', 587),
#  ('vio', 587),
#  ('5', 586),
#  ('realmente', 584),
#  ('querida', 584),
#  ('comandante', 584),
#  ('pobre', 583),
#  ('nuestros', 582),
#  ('paz', 581),
#  ('fuego', 580),
#  ('|', 579),
#  ('esperando', 578),
#  ('forma', 577),
#  ('querido', 577),
#  ('mía', 576),
#  ('ocurre', 573),
#  ('diez', 570),
#  ('ido', 570),
#  ('escucha', 569),
#  ('sola', 567),
#  ('dólares', 567),
#  ('ia', 565),
#  ('you', 565),
#  ('debes', 561),
#  ('tomar', 560),
#  ('10', 559),
#  ('wilfrid', 559),
#  ('cerca', 558),
#  ('tío', 558),
#  ('culpa', 557),
#  ('enseguida', 557),
#  ('dar', 554),
#  ('misma', 551),
#  ('lejos', 548),
#  ('fácil', 547),
#  ('lleva', 547),
#  ('dame', 546),
#  ('piensa', 543),
#  ('vino', 543),
#  ('muchacho', 540),
#  ('inocente', 538),
#  ('palabra', 537),
#  ('espere', 536),
#  ('incluso', 532),
#  ('final', 531),
#  ('ello', 531),
#  ('tranquilo', 531),
#  ('par', 531),
#  ('doc', 530),
#  ('última', 529),
#  ('quieren', 528),
#  ('hará', 526),
#  ('majestad', 526),
#  ('difícil', 523),
#  ('clase', 521),
#  ('habitación', 521),
#  ('año', 519),
#  ('demás', 519),
#  ('seguir', 518),
#  ('hago', 518),
#  ('dejar', 517),
#  ('disculpe', 516),
#  ('coche', 516),
#  ('pienso', 515),
#  ('juicio', 514),
#  ('imposible', 513),
#  ('abajo', 513),
#  ('niños', 512),
#  ('significa', 512),
#  ('i', 511),
#  ('sargento', 508),
#  ('caballero', 506),
#  ('esperar', 505),
#  ('avión', 505),
#  ('saben', 504),
#  ('charlie', 504),
#  ('pasó', 503),
#  ('podía', 501),
#  ('estará', 499),
#  ('cama', 498),
#  ('sir', 493),
#  ('perro', 492),
#  ('hacen', 492),
#  ('poder', 491),
#  ('oficial', 490),
#  ('algunos', 489),
#  ('dicen', 489),
#  ('prisa', 489),
#  ('primer', 489),
#  ('peor', 489),
#  ('silencio', 485),
#  ('comer', 481),
#  ('manera', 481),
#  ('señoría', 481),
#  ('además', 479),
#  ('medio', 477),
#  ('esté', 476),
#  ('familia', 473),
#  ('sentido', 473),
#  ('compañía', 471),
#  ('derecho', 470),
#  ('cielo', 469),
#  ('allá', 469),
#  ('fui', 468),
#  ('grande', 465),
#  ('dijiste', 464),
#  ('vuelve', 464),
#  ('puente', 463),
#  ('conoce', 460),
#  ('perder', 458),
#  ('navaja', 458),
#  ('carta', 457),
#  ('pase', 457),
#  ('verte', 455),
#  ('llegó', 453),
#  ('vivo', 452),
#  ('2', 451),
#  ('fiesta', 449),
#  ('chicas', 449),
#  ('trata', 448),
#  ('dime', 447),
#  ('ei', 447),
#  ('asesinato', 446),
#  ('exactamente', 445),
#  ('pequeño', 445),
#  ('médico', 445),
#  ('parís', 444),
#  ('mucha', 441),
#  ('viaje', 440),
#  ('frente', 437),
#  ('castillo', 436),
#  ('entrar', 435),
#  ('vuelva', 435),
#  ('hagas', 434),
#  ('pena', 434),
#  ('libre', 431),
#  ('amable', 431),
#  ('caballo', 431),
#  ('jamás', 431),
#  ('barco', 431),
#  ('dr', 430),
#  ('oficiales', 428),
#  ('oiga', 427),
#  ('llegado', 426),
#  ('haría', 426),
#  ('anoche', 425),
#  ('llevo', 424),
#  ('abogado', 424),
#  ('café', 423),
#  ('vuelto', 422),
#  ('persona', 421),
#  ('tendrá', 421),
#  ('paso', 421),
#  ('luz', 421),
#  ('vuelta', 420),
#  ('ojalá', 418),
#  ('oportunidad', 417),
#  ('quisiera', 417),
#  ('recuerdo', 417),
#  ('empezar', 415),
#  ('país', 414),
#  ('1', 414),
#  ('ejército', 413),
#  ('pequeña', 411),
#  ('realidad', 410),
#  ('terminado', 410),
#  ('modo', 409),
#  ('cambio', 409),
#  ('atención', 409),
#  ('veras', 408),
#  ('don', 408),
#  ('atrás', 407),
#  ('acusado', 407),
#  ('idiota', 406),
#  ('cuerpo', 405),
#  ('llamo', 405),
#  ('chicos', 404),
#  ('leonard', 403),
#  ('palabras', 402),
#  ('enemigo', 401),
#  ('éste', 401),
#  ('minuto', 401),
#  ('trago', 399),
#  ('hijos', 399),
#  ('hermana', 397),
#  ('eran', 397),
#  ('malo', 395),
#  ('amo', 394),
#  ('estaré', 394),
#  ('temo', 394),
#  ('3', 393),
#  ('deberías', 393),
#  ('preguntas', 393),
#  ('maravilloso', 393),
#  ('órdenes', 393),
#  ('quiera', 392),
#  ('hospital', 390),
#  ('johnny', 388),
#  ('tuvo', 386),
#  ('ayer', 385),
#  ('alegro', 384),
#  ('prueba', 384),
#  ('mas', 383),
#  ('decirle', 383),
#  ('to', 383),
#  ('comida', 381),
#  ('20', 378),
#  ('campo', 377),
#  ('di', 374),
#  ('perdón', 374),
#  ('dio', 374),
#  ('resto', 373),
#  ('sino', 373),
#  ('encima', 372),
#  ('queremos', 372),
#  ('duda', 370),
#  ('pensando', 369),
#  ('música', 369),
#  ('ocurrió', 369),
#  ('ante', 369),
#  ('ataque', 369),
#  ('placer', 368),
#  ('anciano', 368),
#  ('vive', 366),
#  ('juego', 365),
#  ('doy', 365),
#  ('beber', 364),
#  ('sabemos', 364),
#  ('bonito', 364),
#  ('último', 363),
#  ('tendré', 363),
#  ('recuerda', 363),
#  ('mil', 363),
#  ('preocupes', 363),
#  ('ben', 363),
#  ('gusto', 362),
#  ('-', 362),
#  ('15', 360),
#  ('muchachos', 360),
#  ('deben', 359),
#  ('vista', 358),
#  ('volveré', 358),
#  ('sala', 358),
#  ('hotel', 358),
#  ('siente', 356),
#  ('cuarto', 356),
#  ('llamar', 355),
#  ('señores', 353),
#  ('frío', 352),
#  ('ay', 352),
#  ('bailar', 352),
#  ('pie', 351),
#  ('esperaba', 350),
#  ('tuve', 350),
#  ('perdone', 350),
#  ('noticias', 349),
#  ('dan', 348),
#  ('semanas', 348),
#  ('ganado', 347),
#  ('nuestras', 346),
#  ('personas', 346),
#  ('cállate', 345),
#  ('río', 345),
#  ('norte', 344),
#  ('encontrado', 344),
#  ('detrás', 343),
#  ('creer', 343),
#  ('deberíamos', 341),
#  ('vosotros', 340),
#  ('daño', 340),
#  ('joey', 340),
#  ('miki', 340),
#  ('verlo', 339),
#  ('aqui', 339),
#  ('dejado', 338),
#  ('podríamos', 338),
#  ('oír', 336),
#  ('profesor', 336),
#  ('honor', 336),
#  ('llamado', 335),
#  ('fuerza', 335),
#  ('jurado', 335),
#  ('digas', 335),
#  ('llevar', 334),
#  ('calle', 334),
#  ('voz', 333),
#  ('cartas', 332),
#  ('largo', 332),
#  ('segura', 331),
#  ('única', 331),
#  ('pensado', 330),
#  ('hija', 329),
#  ('acaba', 329),
#  ('gustan', 328),
#  ('permiso', 328),
#  ('estuvo', 328),
#  ('haremos', 327),
#  ('siéntate', 327),
#  ('armas', 327),
#  ('secreto', 327),
#  ('otras', 325),
#  ('piso', 325),
#  ('seas', 325),
#  ('rey', 324),
#  ('error', 324),
#  ('sal', 324),
#  ('soldados', 324),
#  ('ley', 324),
#  ('mitad', 323),
#  ('aire', 323),
#  ('siete', 322),
#  ('tendremos', 322),
#  ('habéis', 322),
#  ('wyatt', 322),
#  ('hacemos', 321),
#  ('hambre', 321),
#  ('teléfono', 321),
#  ('oyó', 321),
#  ('estuve', 320),
#  ('interesante', 320),
#  ('mala', 320),
#  ('?"', 319),
#  ('hechos', 319),
#  ('llega', 318),
#  ('trato', 318),
#  ('creí', 317),
#  ('siéntese', 317),
#  ('acaso', 316),
#  ('horrible', 316),
#  ('dile', 316),
#  ('anda', 316),
#  ('matado', 316),
#  ('marina', 315),
#  ('estaban', 314),
#  ('york', 313),
#  ('pagar', 312),
#  ('hiciste', 312),
#  ('marcha', 312),
#  ('buscando', 312),
#  ('encontrar', 311),
#  ('inspector', 311),
#  ('especial', 310),
#  ('verás', 310),
#  ('personal', 310),
#  ('quieras', 309),
#  ('cambiado', 309),
#  ('diablo', 309),
#  ('eddie', 309),
#  ('deje', 308),
#  ('ésta', 308),
#  ('pruebas', 307),
#  ('buscar', 307),
#  ('okayo', 307),
#  ('oficina', 306),
#  ('seré', 306),
#  ('media', 306),
#  ('caballos', 306),
#  ('san', 306),
#  ('estabas', 305),
#  ('vámonos', 305),
#  ('irme', 304),
#  ('iremos', 304),
#  ('mike', 304),
#  ('siendo', 302),
#  ('tras', 302),
#  ('pone', 302),
#  ('6', 302),
#  ('decía', 301),
#  ('hablas', 300),
#  ('abre', 300),
#  ('mató', 300),
#  ('ropa', 299),
#  ('valor', 299),
#  ('opinión', 298),
#  ('arma', 298),
#  ('acabo', 297),
#  ('fueron', 296),
#  ('vayas', 296),
#  ('"¿', 296),
#  ('ten', 296),
#  ('bosque', 296),
#  ('tonterías', 295),
#  ('sol', 294),
#  ('creía', 294),
#  ('pensaba', 292),
#  ('servicio', 291),
#  ('max', 291),
#  ('pudo', 290),
#  ('libro', 290),
#  ('correcto', 289),
#  ('terrible', 289),
#  ('french', 289),
#  ('negocio', 288),
#  ('acabó', 288),
#  ('saberlo', 288),
#  ('4', 288),
#  ('veamos', 288),
#  ('tribunal', 288),
#  ('verme', 287),
#  ('diría', 287),
#  ('deprisa', 287),
#  ('odio', 287),
#  ('murió', 286),
#  ('piensas', 286),
#  ('hermosa', 286),
#  ('lista', 286),
#  ('salud', 285),
#  ('según', 285),
#  ('metros', 284),
#  ('casado', 283),
#  ('it', 283),
#  ('segundo', 282),
#  ('preocupe', 282),
#  ('tonto', 281),
#  ('algunas', 281),
#  ('existe', 281),
#  ('motivo', 281),
#  ('gracioso', 280),
#  ('muertos', 280),
#  ('daré', 280),
#  ('listos', 279),
#  ('cárcel', 279),
#  ('solitario', 279),
#  ('ejemplo', 279),
#  ('suyo', 278),
#  ('dígame', 278),
#  ('miren', 277),
#  ('cualquiera', 277),
#  ('christine', 277),
#  ('borracho', 276),
#  ('conoces', 275),
#  ('grandes', 275),
#  ('entendido', 275),
#  ('suelo', 275),
#  ('delante', 275),
#  ('toca', 275),
#  ('consejo', 274),
#  ('espíritu', 274),
#  ('verla', 273),
#  ('tuya', 273),
#  ('copa', 273),
#  ('estaría', 272),
#  ('necesario', 272),
#  ('mando', 271),
#  ('irá', 271),
#  ('joe', 271),
#  ('podrías', 270),
#  ('uds', 270),
#  ('papel', 269),
#  ('enfermo', 269),
#  ('poner', 268),
#  ('Éste', 268),
#  ('abuela', 268),
#  ('trae', 267),
#  ('das', 267),
#  ('cambiar', 267),
#  ('agradable', 267),
#  ('veremos', 266),
#  ('dama', 266),
#  ('edad', 265),
#  ('loca', 264),
#  ('vienen', 264),
#  ('comprendo', 264),
#  ('verle', 264),
#  ('paul', 264),
#  ('entra', 263),
#  ('vieja', 263),
#  ('extraño', 263),
#  ('segundos', 263),
#  ('jugar', 262),
#  ('boca', 262),
#  ('mes', 262),
#  ('tome', 262),
#  ('acabado', 261),
#  ('niña', 261),
#  ('ocho', 261),
#  ('hacía', 261),
#  ('oro', 260),
#  ('dax', 260),
#  ('ventana', 259),
#  ('entiende', 259),
#  ('herido', 259),
#  ('calma', 258),
#  ('pudiera', 258),
#  ('tendrás', 258),
#  ('12', 258),
#  ('cena', 258),
#  ('defensa', 258),
#  ('pistola', 258),
#  ('razonable', 257),
#  ('canción', 257),
#  ('vestido', 257),
#  ('rhodes', 257),
#  ('decirte', 256),
#  ('informe', 256),
#  ('verá', 256),
#  ('bonita', 255),
#  ('vemos', 255),
#  ('interesa', 255),
#  ('junto', 255),
#  ('darle', 255),
#  ('testigo', 255),
#  ('encuentra', 254),
#  ('hable', 254),
#  ('divertido', 254),
#  ('matrimonio', 253),
#  ('sucede', 253),
#  ('vd', 253),
#  ('crimen', 252),
#  ('lamento', 251),
#  ('regalo', 251),
#  ('negro', 251),
#  ('Ésta', 251),
#  ('george', 251),
#  ('baja', 250),
#  ('dejes', 250),
#  ('cine', 250),
#  ('cuántos', 250),
#  ('cabo', 250),
#  ('tuyo', 250),
#  ('#', 250),
#  ('rico', 249),
#  ('solos', 249),
#  ('ayudar', 249),
#  ('tardes', 249),
#  ('cenar', 248),
#  ('principio', 248),
#  ('escuche', 248),
#  ('conseguir', 247),
#  ('guardia', 247),
#  ('vergüenza', 247),
#  ('carne', 246),
#  ('intenta', 246),
#  ('corte', 246),
#  ('calor', 246),
#  ('sorpresa', 246),
#  ('tienda', 246),
#  ('jesse', 246),
#  ('duro', 245),
#  ('necesitamos', 245),
#  ('presidente', 245),
#  ('respuesta', 245),
#  ...]

# %%
#Check de la puntuacion
import string 
print(string.punctuation)

punt_dict = {}
for word in c:
    for punt in string.punctuation:#",.¿?¡!\":()-{}":
        if punt in word:
            if len(word)>1 and c[word]>3:
                punt_dict[word] = c[word]
c2 = Counter(punt_dict)
c2.most_common()
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# [('?"', 319),
#  ('"¿', 296),
#  ('"el', 196),
#  ('"la', 179),
#  ('"no', 168),
#  ('dijo:', 147),
#  ('!"', 130),
#  ("ma'am", 119),
#  ('"¡', 110),
#  ('dije:', 110),
#  ('brogan-moore', 104),
#  ('"te', 99),
#  ('dice:', 91),
#  ('"y', 90),
#  ('rau-ru', 88),
#  ('"culpable"', 71),
#  ('"inocente"', 64),
#  ('"mi', 55),
#  ('esto:', 54),
#  ('21:25', 54),
#  ('"si', 53),
#  ('10:00', 53),
#  ('dos:', 53),
#  ('cosa:', 50),
#  ('"se', 47),
#  ('"los', 45),
#  ("'n'", 45),
#  ('7:00', 42),
#  ('hana-ogi', 41),
#  ('8:00', 40),
#  ('"para', 40),
#  ('mataré"', 40),
#  ('anne-claire', 39),
#  ('"sheriff"', 39),
#  ('"señor"', 37),
#  ('es:', 37),
#  ('"las', 36),
#  ('decir:', 36),
#  ('"por', 35),
#  ('"que', 35),
#  ('22:10', 34),
#  ('10%', 34),
#  ('dicho:', 33),
#  ('3:00', 33),
#  ("i'm", 33),
#  ('4:00', 32),
#  ('"sí"', 32),
#  ('"hoy', 31),
#  ('"una', 31),
#  ('"querido', 31),
#  ("it's", 31),
#  ('"en', 30),
#  ('así:', 30),
#  ('bate-huevos', 30),
#  ('decía:', 29),
#  ('"no"', 28),
#  ("don't", 28),
#  ('una:', 28),
#  ('tres:', 27),
#  ('"es', 26),
#  ('por:', 26),
#  ('digo:', 26),
#  ('"pero', 26),
#  ('32-58-78', 26),
#  ('"a"', 25),
#  ('21:30', 25),
#  ('"un', 24),
#  ('21:26', 24),
#  ('|¡', 24),
#  ('matar"', 24),
#  ('peso:', 24),
#  ('uno:', 23),
#  ('50%', 23),
#  ('gritar:', 23),
#  ('2:30', 22),
#  ('"lo', 21),
#  ('dirán:', 21),
#  ('19:30', 21),
#  ("there's", 21),
#  ('|¿', 21),
#  ('"le', 20),
#  ('pregunta:', 20),
#  ('"de', 20),
#  ('"con', 20),
#  ('cuatro:', 20),
#  ('"a', 20),
#  ('mckay"', 20),
#  ('velocidad:', 19),
#  ('"me', 19),
#  ('"telaraña"', 19),
#  ("that's", 19),
#  ('"m"', 19),
#  ('1-9-0', 18),
#  ('"sólo', 18),
#  ('mikado"', 18),
#  ('"houston', 18),
#  ('station"', 18),
#  ("c'est", 18),
#  ('(llora)', 18),
#  ('pensé:', 17),
#  ('8:30', 17),
#  ('$10', 17),
#  ("o'brien", 17),
#  ('señor"', 17),
#  ('todo:', 17),
#  ('diga:', 17),
#  ('-¿', 17),
#  ('$5000', 17),
#  ('5:00', 17),
#  ('allison:', 17),
#  ('x-3', 17),
#  ('música:', 16),
#  ("didn't", 16),
#  ('5:30', 16),
#  ("you're", 16),
#  ('gabriella"', 16),
#  ('3:10', 16),
#  ('fue:', 16),
#  ('"l"', 15),
#  ('40%', 15),
#  ('"sr', 15),
#  ('matado"', 15),
#  ('"meineid"', 15),
#  ('$5', 15),
#  ('6:30', 15),
#  ('"después', 15),
#  ('repito:', 15),
#  ('11:00', 15),
#  ("i'll", 15),
#  ('girls"', 15),
#  ('altura:', 15),
#  ('"yo', 14),
#  ('más"', 14),
#  ('"este', 14),
#  ("john's", 14),
#  ('9:00', 14),
#  ("we're", 14),
#  ("they're", 14),
#  ('"tengo', 14),
#  ('son:', 14),
#  ('"solitario', 14),
#  ('todos"', 14),
#  ('cinco:', 14),
#  ('saluda"', 14),
#  ('segundo:', 14),
#  ('"duda', 14),
#  ('razonable"', 14),
#  ('alemán)', 14),
#  ('b-52', 14),
#  ('"su', 13),
#  ('"qué', 13),
#  ('$200', 13),
#  ('$25', 13),
#  ('-¡', 13),
#  ("ain't", 13),
#  ('"life"', 13),
#  ('8:45', 13),
#  ('saint-auban', 13),
#  ('siguiente:', 13),
#  ('paraíso"', 13),
#  ('$3', 13),
#  ('1-5', 13),
#  ('sonido:', 12),
#  ('"sí', 12),
#  ('guión:', 12),
#  ('"bate-huevos"', 12),
#  ('21:00', 12),
#  ('"leonard', 12),
#  ('"fraulein"', 12),
#  ('"gemütlich"', 12),
#  ('"como', 12),
#  ('dirá:', 12),
#  ('"aquí', 12),
#  ('"doctor', 12),
#  ('strip-tease', 12),
#  ('2:00', 12),
#  ('japanese)', 12),
#  ('aquí"', 12),
#  ('"geneva"', 12),
#  ("i'aigle", 12),
#  ('12:10', 12),
#  ('4-7', 12),
#  ('"the', 11),
#  ('"voy', 11),
#  ('contesté:', 11),
#  ('dirección:', 11),
#  ('"quiero', 11),
#  ('"tu', 11),
#  ('$2', 11),
#  ('6:00', 11),
#  ('$20', 11),
#  ('bien"', 11),
#  ('12:00', 11),
#  ('05:30', 11),
#  ("i'd", 11),
#  ('(man', 11),
#  ('volador"', 11),
#  ('"ahora', 10),
#  ('dijeron:', 10),
#  ('reparto:', 10),
#  ('realización:', 10),
#  ('cámaras:', 10),
#  ('yamashita:', 10),
#  ('"al', 10),
#  ('"ginjiro', 10),
#  ('max:', 10),
#  ('quiero"', 10),
#  ('mt-3', 10),
#  ('"cuando', 10),
#  ('dios"', 10),
#  ('"sin', 10),
#  ('$1000', 10),
#  ('$100', 10),
#  ('"o', 10),
#  ('17:00', 10),
#  ('coca-cola', 10),
#  ('casa"', 10),
#  ('"hola"', 10),
#  ('"estoy', 10),
#  ('anti-materia', 10),
#  ('f-86', 10),
#  ('rhodes"', 10),
#  ('bomba"', 10),
#  ('(solloza)', 10),
#  ('"bueno', 9),
#  ('9:30', 9),
#  ('$50', 9),
#  ('tarde"', 9),
#  ('"abri', 9),
#  ('l"', 9),
#  ('"mañana', 9),
#  ('30%', 9),
#  ('80%', 9),
#  ('14:30', 9),
#  ('22:40', 9),
#  ('"perjurio"', 9),
#  ('21:40', 9),
#  ('bien:', 9),
#  ('7:30', 9),
#  ('visiontext:', 9),
#  ('100%', 9),
#  ('15:00', 9),
#  ('nota:', 9),
#  ('"cabiria', 9),
#  ('"nuestro', 9),
#  ('"querida', 9),
#  ('"jamás', 9),
#  ('"ahí', 9),
#  ('recuerda:', 9),
#  ('5%', 9),
#  ('"prisionero', 9),
#  ('roll"', 9),
#  ('vida"', 9),
#  ('ver:', 9),
#  ('05:15', 9),
#  ('diabilis"', 9),
#  ('talla:', 9),
#  ('gruver-san', 9),
#  ('04:00', 9),
#  ('12-50', 9),
#  ('(música', 9),
#  ('como:', 8),
#  ('director:', 8),
#  ('más:', 8),
#  ('cosas:', 8),
#  ('mismo:', 8),
#  ('otra:', 8),
#  ('"c"', 8),
#  ('"podría', 8),
#  ('"recuerda', 8),
#  ('qué"', 8),
#  ('preguntan:', 8),
#  ('yo"', 8),
#  ('"amén"', 8),
#  ('está:', 8),
#  ('"buenas', 8),
#  ('distancia:', 8),
#  ('días"', 8),
#  ('importante:', 8),
#  ('"ellos"', 8),
#  ('"intentarán"', 8),
#  ('angela:', 8),
#  ('"cariño"', 8),
#  ('sonreír"', 8),
#  ('"e"', 8),
#  ('"apagábamos"', 8),
#  ('ti"', 8),
#  ('"viviendo"', 8),
#  ('"tienes', 8),
#  ('"rossi"', 8),
#  ('diciendo:', 8),
#  ('"correr"', 8),
#  ('"doctor"', 8),
#  ('"t', 8),
#  ('mujeres"', 8),
#  ('"buque', 8),
#  ('1-9-7', 8),
#  ('b-36', 8),
#  ('fácil:', 8),
#  ('"hay', 8),
#  ('9:45', 8),
#  ('6:15', 8),
#  ('--¡', 8),
#  ('éstos:', 8),
#  ('profundo:', 8),
#  ('ponía:', 8),
#  ('negarnos"', 8),
#  ('desgracia"', 8),
#  ('3:', 8),
#  ('complejo:', 8),
#  ('intento"', 8),
#  ('n-l-Ñ-o:', 8),
#  ('contra-interrogatorio', 8),
#  ('"bofetadas"', 8),
#  ('"puñetazos"', 8),
#  ('primero:', 8),
#  ('triste:', 8),
#  ('"rocky', 8),
#  ('mátale"', 8),
#  ('"tiro', 8),
#  ('c-a-r-e-y', 8),
#  ('(teléfono)', 8),
#  ('dijiste:', 7),
#  ('ivanovich:', 7),
#  ('mark:', 7),
#  ('irina:', 7),
#  ('stepan:', 7),
#  ('abuela:', 7),
#  ('chernov:', 7),
#  ('mijailovna:', 7),
#  ('"difícilmente"', 7),
#  ('"medicina', 7),
#  ('especial"', 7),
#  ('despedir:', 7),
#  ('"bienaventurados', 7),
#  ('4%', 7),
#  ('"algo', 7),
#  ('"auf', 7),
#  ('wiedersehen"', 7),
#  ('22:00', 7),
#  ('"p', 7),
#  ('"su"', 7),
#  ('"ei', 7),
#  ('"ha', 7),
#  ('12:30', 7),
#  ('"poco', 7),
#  ('joey"', 7),
#  ('""el', 7),
#  ('$500', 7),
#  ('dices:', 7),
#  ('cha-cha-cha', 7),
#  ('listnitski:', 7),
#  ('"viene', 7),
#  ('película"', 7),
#  ("isn't", 7),
#  ("what's", 7),
#  ('"todo', 7),
#  ('ahí:', 7),
#  ('"hijo', 7),
#  ('"pocas"', 7),
#  ('"salgamos', 7),
#  ('presenté"', 7),
#  ('"debo', 7),
#  ('nada"', 7),
#  ('estrellas"', 7),
#  ('pensaba:', 7),
#  ('51%', 7),
#  ('mañana"', 7),
#  ('?""', 7),
#  ('jean-pierre', 7),
#  ('fumiko-san', 7),
#  ('--', 6),
#  ('c-47', 6),
#  ('verónica:', 6),
#  ('héroe"', 6),
#  ('"lengua', 6),
#  ('"envuelta', 6),
#  ('"ya', 6),
#  ('"ni', 6),
#  ('señoría"', 6),
#  ('"inns', 6),
#  ('court"', 6),
#  ('"dentista"', 6),
#  ('cómo:', 6),
#  ('"jawohl"', 6),
#  ('"puede', 6),
#  ('corona"', 6),
#  ('240-130', 6),
#  ('asesina"', 6),
#  ('"él"', 6),
#  ('"ella"', 6),
#  ('"ello"', 6),
#  ('1"', 6),
#  ('ama-dama', 6),
#  ('"regazo', 6),
#  ('amante"', 6),
#  ('"old', 6),
#  ('baley"', 6),
#  ('"esposo"', 6),
#  ('jurado;', 6),
#  ('"morena', 6),
#  ('colgada"', 6),
#  ('esposa"', 6),
#  ('"meinied"', 6),
#  ('ultimátum:', 6),
#  ('23:25', 6),
#  ('"esta"', 6),
#  ('alemán-húngaro', 6),
#  ('"oh', 6),
#  ('"rayo"', 6),
#  ('m-47', 6),
#  ('bx-89', 6),
#  ('$40', 6),
#  ('"dios', 6),
#  ('20%', 6),
#  ('francisco"', 6),
#  ('"joey', 6),
#  ('señorita--', 6),
#  ('""joey', 6),
#  ('mmm-hmm', 6),
#  ('11:', 6),
#  ('"dos', 6),
#  ('"hombre', 6),
#  ('koshevaia:', 6),
#  ('objetivo:', 6),
#  ('"hijo"', 6),
#  ('dólares"', 6),
#  ('parte"', 6),
#  ('verde"', 6),
#  ('"firefoot"', 6),
#  ("you've", 6),
#  ("wouldn't", 6),
#  ("he's", 6),
#  ('"era', 6),
#  ("'tres", 6),
#  ("pes'", 6),
#  ('"barry', 6),
#  ("d'ange", 6),
#  ('"veo', 6),
#  ('"Éste', 6),
#  ('disculparme"', 6),
#  ('#no', 6),
#  ('"florita"', 6),
#  ('60-40', 6),
#  ('60%', 6),
#  ('"iglesia', 6),
#  ('|en', 6),
#  ('|por', 6),
#  ('vamos|a', 6),
#  ('"prisa"', 6),
#  ('arkansas"', 6),
#  ('"mi"', 6),
#  ('perdonarme"', 6),
#  ('"showroom"', 6),
#  ('escurridizo"', 6),
#  ('17:', 6),
#  ('18:', 6),
#  ('19:', 6),
#  ('12:', 6),
#  ('13:', 6),
#  ('exportador-importador', 6),
#  ('15:', 6),
#  ('bam-balabám-bam', 6),
#  ('"amable', 6),
#  ('"x"', 6),
#  ('"caserna', 6),
#  ('"púas"', 6),
#  ('mensajería:', 6),
#  ('disposición"', 6),
#  ('"haré', 6),
#  ('lograrlo"', 6),
#  ('n-i-Ñ-o', 6),
#  ('$6', 6),
#  ('"venta', 6),
#  ('sugerida"', 6),
#  ('chico:', 6),
#  ('cariño"', 6),
#  ('mato"', 6),
#  ('"pánico"', 6),
#  ('recuerden:', 6),
#  ('"adivinen', 6),
#  ('ocurrió:', 6),
#  ('"supuso"', 6),
#  ('"escapar"', 6),
#  ('permiso"', 6),
#  ('"notifican"', 6),
#  ('lame"', 6),
#  ('"ling"', 6),
#  ('"long"', 6),
#  ('(¿', 6),
#  ('después"', 6),
#  ('mont-blanc', 6),
#  ('futuro"', 5),
#  ('"muy', 5),
#  ("o'bannion", 5),
#  ('1-7', 5),
#  ('artística:', 5),
#  ('ejéricto:', 5),
#  ('decorado:', 5),
#  ('(vladimir):', 5),
#  ('mismo"', 5),
#  ('terror"', 5),
#  ('muerte:', 5),
#  ('"razonable"', 5),
#  ('"ordenó"', 5),
#  ('justamente:', 5),
#  ('"soldados', 5),
#  ('ingleses"', 5),
#  ('jefe:', 5),
#  ('principio"', 5),
#  ('febrero"', 5),
#  ('mayo"', 5),
#  ('ceilán"', 5),
#  ('bangkok-rangoon', 5),
#  ('"continuemos', 5),
#  ('servicio:', 5),
#  ('diviértanse"', 5),
#  ('norma"', 5),
#  ('0-1-2-3-4-5-6-7', 5),
#  ('"trabajar', 5),
#  ('alegría"', 5),
#  ('beri-beri', 5),
#  ('"soldados"', 5),
#  ('"trabajarán', 5),
#  ('600"', 5),
#  ('empezar"', 5),
#  ('"adorada', 5),
#  ('teniente"', 5),
#  ('especial:', 5),
#  ('"envíenlo', 5),
#  ('suplantación"', 5),
#  ('prevista:', 5),
#  ('diviertan"', 5),
#  ('febrero-mayo', 5),
#  ('mando:', 5),
#  ('pero--', 5),
#  ('que--', 5),
#  ('la-di-dah', 5),
#  ('guardian"', 5),
#  ("'samurai'", 5),
#  ('"virgen"', 5),
#  ('vive-bien', 5),
#  ('"envenenamiento"', 5),
#  ('"nunca', 5),
#  ('"milord"', 5),
#  ('río:', 5),
#  ('condición:', 5),
#  ('"hechos"', 5),
#  ('siempre:', 5),
#  ('días:', 5),
#  ('ésta:', 5),
#  ('"nada', 5),
#  ('decorados:', 5),
#  ('muerte"', 5),
#  ('"he', 5),
#  ('consejo:', 5),
#  ('escucha:', 5),
#  ('viento:', 5),
#  ('$1', 5),
#  ('algo:', 5),
#  ('fotografía:', 5),
#  ("o'hara", 5),
#  ('10:30', 5),
#  ('"i', 5),
#  ('"amigos', 5),
#  ('"charlie', 5),
#  ('"adiós', 5),
#  ('noches"', 5),
#  ('palabra:', 5),
#  ('marina"', 5),
#  ('hijo"', 5),
#  ('"tú', 5),
#  ('ruso-japonesa', 5),
#  ('pienso:', 5),
#  ('operaciones:', 5),
#  ('ayer:', 5),
#  ("d'artagnan", 5),
#  ('"mamá"', 5),
#  ('25%', 5),
#  ('mejor:', 5),
#  ("couldn't", 5),
#  ('"madre', 5),
#  ('"iré', 5),
#  ('emborracharé"', 5),
#  ("'no", 5),
#  ('2:40', 5),
#  ('"señora', 5),
#  ('"barco', 5),
#  ('"asesino"', 5),
#  ('seguro:', 5),
#  ('"joven', 5),
#  ('"siempre', 5),
#  ('"o"', 5),
#  ('dime:', 5),
#  ('primero"', 5),
#  ('"mis', 5),
#  ('"amor"', 5),
#  ('$3000', 5),
#  ('permitido"', 5),
#  ("o'faolain", 5),
#  ('3%', 5),
#  ('multitud"', 5),
#  ('"durante', 5),
#  ('2%', 5),
#  ('*-', 5),
#  ('10:15', 5),
#  ('"especie"', 5),
#  ('"preparen', 5),
#  ('fuego"', 5),
#  ('involucrados:', 5),
#  ('yo--', 5),
#  ('hombres:', 5),
#  ('"segundo', 5),
#  ('instancia"', 5),
#  ('pues--', 5),
#  ('6:05', 5),
#  ('hace:', 5),
#  ('anteojos"', 5),
#  ('""', 5),
#  ('""¿', 5),
#  ('ustedes"', 5),
#  ('prueba:', 5),
#  ('"quizá', 5),
#  ('(habla', 5),
#  ('infierno"', 4),
#  ('"será', 4),
#  ('preguntó:', 4),
#  ("mcdonald's", 4),
#  ('$250', 4),
#  ('es--', 4),
#  ('montaje:', 4),
#  ('di:', 4),
#  ('(el', 4),
#  ('km/h', 4),
#  ('90%', 4),
#  ('subtítulos:', 4),
#  ('mundo"', 4),
#  ('borís:', 4),
#  ('guía;', 4),
#  ('amor"', 4),
#  ('mundo:', 4),
#  ('"agua', 4),
#  ('ríe"', 4),
#  ('"bajando', 4),
#  ('territorial"', 4),
#  ('testigo:', 4),
#  ('todos:', 4),
#  ('encaminado"', 4),
#  ('n%', 4),
#  ('mount-lavinia', 4),
#  ('"abandonada', 4),
#  ('el--', 4),
#  ('"Él"', 4),
#  ("i'argent", 4),
#  ('"soy', 4),
#  ('"porque', 4),
#  ("shepherd's", 4),
#  ("'45", 4),
#  ('verdad:', 4),
#  ('casa;', 4),
#  ('amo"', 4),
#  ('"amor', 4),
#  ('sur"', 4),
#  ('"imposible', 4),
#  ('"señor', 4),
#  ('triunfante;', 4),
#  ('cansado;', 4),
#  ('dirá;', 4),
#  ('listos;', 4),
#  ('oportunidad;', 4),
#  ('alto;', 4),
#  ('eso;', 4),
#  ('presagio;', 4),
#  ('washizu;', 4),
#  ('extraño;', 4),
#  ('estropeada;', 4),
#  ('enemigo;', 4),
#  ('sugiyama:', 4),
#  ('base:', 4),
#  ('importante"', 4),
#  ('"chico"', 4),
#  ('"chic"', 4),
#  ('corazón:', 4),
#  ('cuestión:', 4),
#  ('"fin"', 4),
#  ('"chando"', 4),
#  ('"gato"', 4),
#  ('"mamá', 4),
#  ('"tío', 4),
#  ('"después"', 4),
#  ('"está', 4),
#  ('6%', 4),
#  ('english"', 4),
#  ('evans"', 4),
#  ('compañía"', 4),
#  ('$4000', 4),
#  ('""se', 4),
#  ('ropa"', 4),
#  ('$15', 4),
#  ('$400', 4),
#  ('"e', 4),
#  ('"ven', 4),
#  ('mí"', 4),
#  ('cross-canada', 4),
#  ('"lluvia"', 4),
#  ('oro"', 4),
#  ('"cualquier', 4),
#  ('lema:', 4),
#  ('"tuyo', 4),
#  ("romano's", 4),
#  ('"espero', 4),
#  ('nosotros"', 4),
#  ('"debe', 4),
#  ('mío"', 4),
#  ('decirle:', 4),
#  ('español:', 4),
#  ('principales:', 4),
#  ('grigori:', 4),
#  ('daria:', 4),
#  ('(dunita):', 4),
#  ('axinia:', 4),
#  ('natalia:', 4),
#  ('(mitka):', 4),
#  ('koshevói:', 4),
#  ('stokman:', 4),
#  ('ktoliárov:', 4),
#  ('diré:', 4),
#  ('respondí:', 4),
#  ('general:', 4),
#  ('a-ha-ha', 4),
#  ('marcación:', 4),
#  ('torpedo:', 4),
#  ('escriba:', 4),
#  ('"soldado', 4),
#  ("o'meara", 4),
#  ('"lamento', 4),
#  ('gioconda"', 4),
#  ('musical:', 4),
#  ('"gentileza"', 4),
#  ('perdone"', 4),
#  ('"muchacho', 4),
#  ('"santo', 4),
#  ('(chuckling)', 4),
#  ("wasn't", 4),
#  ("won't", 4),
#  ("they'll", 4),
#  ('(men', 4),
#  ("they've", 4),
#  ('(sings', 4),
#  ('"don\'t', 4),
#  ('tree")', 4),
#  ("we'll", 4),
#  ('criado"', 4),
#  ('vez:', 4),
#  ('"mandar"', 4),
#  ('grano:', 4),
#  ('"éste', 4),
#  ('señor:', 4),
#  ('trabajo"', 4),
#  ('"pequeño', 4),
#  ('jimmy"', 4),
#  ("back's", 4),
#  ("wyatt's", 4),
#  ('"jugadora"', 4),
#  ('"show"', 4),
#  ('"Ésas', 4),
#  ('"seis', 4),
#  ('gritando:', 4),
#  ('"baseball"', 4),
#  ('hora:', 4),
#  ('79-79', 4),
#  ('"sea', 4),
#  ('latitud:', 4),
#  ('tienes:', 4),
#  ('alhambra-93434', 4),
#  ('alhambra-92424', 4),
#  ('"reverendo', 4),
#  ('"sé', 4),
#  ('"vuelvo', 4),
#  ('enseguida"', 4),
#  ('resumiendo:', 4),
#  ('#me', 4),
#  ('#el', 4),
#  ('#vierte', 4),
#  ('"ex"', 4),
#  ('apunta:', 4),
#  ('hacer:', 4),
#  ('place"', 4),
#  ('"ti', 4),
#  ('tweed"', 4),
#  ('"fotografía":', 4),
#  ('mundial"', 4),
#  ('hyde:', 4),
#  ('"abusador', 4),
#  ('sexual"', 4),
#  ('"maltratador', 4),
#  ('niños"', 4),
#  ('"vaya', 4),
#  ('cine"', 4),
#  ('"mago"', 4),
#  ('"allí', 4),
#  ('"rye', 4),
#  ('"aleluya', 4),
#  ('"tenía', 4),
#  ('durmiendo"', 4),
#  ('moe"', 4),
#  ('memphis"', 4),
#  ('cambio"', 4),
#  ('washington"', 4),
#  ('pregunto:', 4),
#  ('mucho"', 4),
#  ('"solitarlo', 4),
#  ('18:00', 4),
#  ('"vete', 4),
#  ('"dígale', 4),
#  ('espectáculo"', 4),
#  ('9:15', 4),
#  ('"personal"', 4),
#  ('está;', 4),
#  ('campanera"', 4),
#  ('65%', 4),
#  ('cortesía"', 4),
#  ('corriere"', 4),
#  ('"pata', 4),
#  ('advierto:', 4),
#  ('este:', 4),
#  ('"devolverlo', 4),
#  ('salvo"', 4),
#  ('"abofeteó"', 4),
#  ('"golpeó"', 4),
#  ('"i´m', 4),
#  ('director"', 4),
#  ('puta-lisa', 4),
#  ('nalgas-lisa', 4),
#  ('"granizo', 4),
#  ('"ardiendo', 4),
#  ('ginger-ale', 4),
#  ('"scott', 4),
#  ('"enseguida', 4),
#  ('nakamura-san', 4),
#  ('kelly-san', 4),
#  ('(afligida)', 4),
#  ('(timbre)', 4),
#  ('3:30', 4),
#  ('(continúa', 4),
#  ('música)', 4),
#  ('"conchiglia"', 4)]

# %%
voc.trim(MIN_COUNT)
# Out:
# keep_words 13758 / 57473 = 0.2394

# %%
def has_trimmed_or_unk(spl_snt):
    """ Filter out sentences with trimmed words or words not in the voc
    spl_snt is a list of words"""
    for word in spl_snt:
        if word not in voc.word2index:
            return True

# %%
trm_unk = 0
for i,s in loadLines(corpus,LINES_USED):
    if has_trimmed_or_unk(s): trm_unk +=1
        
full_pairs =  LINES_USED - trm_unk      

print(f"From {LINES_USED} pairs, {full_pairs} does not contain trimmed or unkonwn words,", 
      f"{full_pairs / LINES_USED:.4f} of total")
# Out:
# From 500000 pairs, 401744 does not contain trimmed or unkonwn words, 0.8035 of total

# %%
#aumentando min_count de 3 a 5 el vocabulario pasa de 72510(57%) a 36642(29%), sin embargo las frases aceptadas 
#solo baja un 6%, de 97.33% a 91.27%, o lo que es más impactante, con un tercio del vocabulario total podemos 
#recrear más del 90% del dataset , TODO restestear con diferentes min count cuando este el multicpu

# %%
# spl_snt is a list of words
def indexesFromSentence(spl_snt, voc):
    idxs = []
    for word in spl_snt:
        try:
            idxs += [voc.word2index[word]]
        except:
            idxs += [UNK_token] #word2index["UNK"]=UNK_token
    return idxs + [EOS_token]

def gen_pairs(how_many, voc):
    first_inp = True
    n=0
    for out_idx, out_snt in loadLines(corpus,LINES_USED):
        
        if first_inp: #first cycle, set first input
            inp_idx, inp_snt = out_idx, out_snt
            first_inp = False
            continue

        if inp_idx+1 == out_idx: #frases contiguas (loadLines filter long sentences)
            ok_inp = True if WITH_UNK else not has_trimmed_or_unk(inp_snt) # if WITH_UNK==True, every inp is accepted
            ok_out = not has_trimmed_or_unk(out_snt)
            
            if ok_inp and ok_out: #every word is in Voc
                n+=1
                yield [indexesFromSentence(inp_snt, voc),indexesFromSentence(out_snt, voc)]
        
        if n==how_many:break
        inp_idx, inp_snt = out_idx, out_snt #prepare next cycle
        
for pair in gen_pairs(10,voc): print(pair)
# Out:
# [[8, 9, 3, 10, 11, 12, 13, 14, 3, 14, 15, 16, 3, 5, 17, 7, 2], [18, 19, 20, 21, 22, 11, 23, 16, 24, 25, 26, 27, 28, 29, 25, 26, 5, 30, 7, 2]]
# [[31, 32, 3, 33, 34, 35, 3, 36, 37, 2], [24, 7, 2]]
# [[44, 45, 3, 7, 2], [31, 46, 47, 48, 49, 37, 2]]
# [[31, 46, 47, 48, 49, 37, 2], [31, 50, 14, 51, 48, 49, 52, 37, 2]]
# [[31, 50, 14, 51, 48, 49, 52, 37, 2], [53, 14, 54, 24, 8, 55, 7, 2]]
# [[53, 14, 54, 24, 8, 55, 7, 2], [31, 27, 56, 57, 58, 5, 59, 60, 61, 48, 62, 37, 2]]
# [[3, 66, 67, 68, 69, 70, 7, 2], [47, 48, 71, 72, 7, 73, 74, 75, 2]]
# [[47, 48, 71, 72, 7, 73, 74, 75, 2], [76, 77, 78, 48, 79, 80, 81, 7, 2]]
# [[76, 77, 78, 48, 79, 80, 81, 7, 2], [73, 67, 68, 69, 70, 75, 2]]
# [[73, 67, 68, 69, 70, 75, 2], [82, 83, 11, 84, 85, 48, 67, 7, 2]]

# %%
#check finales paris
for pair in gen_pairs(10,voc): 
    for i in pair:
        snt = []
        for idx in i:
            snt += [voc.index2word[idx]]
        print(*snt)
    print("---")
# Out:
# somos los UNK amigos de la secundaria que UNK que su amistad UNK para siempre . EOS
# aunque las circunstancias del inicio de nuestra amistad no fueron especiales en cierto modo fueron especiales para nosotros . EOS
# ---
# ¿ le UNK el pecho a UNK min ? EOS
# no . EOS
# ---
# debes estar UNK . EOS
# ¿ eso es una pregunta ? EOS
# ---
# ¿ eso es una pregunta ? EOS
# ¿ crees que fue una pregunta idiota ? EOS
# ---
# ¿ crees que fue una pregunta idiota ? EOS
# ey que ya no somos niños . EOS
# ---
# ey que ya no somos niños . EOS
# ¿ en qué estaban pensando para pelear así por una chica ? EOS
# ---
# UNK con piedra papel o tijeras . EOS
# es una buena idea . ¡ hagámoslo ! EOS
# ---
# es una buena idea . ¡ hagámoslo ! EOS
# ok solo haremos una ronda como hombres . EOS
# ---
# ok solo haremos una ronda como hombres . EOS
# ¡ piedra papel o tijeras ! EOS
# ---
# ¡ piedra papel o tijeras ! EOS
# un hombre de verdad usa una piedra . EOS
# ---

# %%
pairs = list(gen_pairs(LINES_USED,voc))

# %%
"""
se obtienen menos pares que lineas usadas, con lineas usadas se crea el diccionario, con ese diccionario elegimos 
las palabras con las que quedarnos, se descartan las lineas con palabras borradas y de ahi solo cogemos los pares
de lineas contiguos
"""
len(pairs)
# Out:
# 395281

# %%
#Guardar pairs y voc
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
with open(save_dir + '/pairs.pkl', 'wb') as file:
    pickle.dump(pairs, file)

with open(save_dir + '/voc.pkl', 'wb') as file:
    voc.__module__ = "Voc"
    pickle.dump(voc, file)

# %%
# # Example for validation of the code
# small_batch_size = 6
# pairs_list = [random.choice(pairs) for _ in range(small_batch_size)]
# batches = batch2TrainData(pairs_list)
# input_variable, lengths, target_variable, mask, max_target_len = batches

# print("input_variable:\n", input_variable)
# print("lengths:", lengths)
# print("target_variable:\n", target_variable)
# print("mask:\n", mask)
# print("max_target_len:", max_target_len)
